# %% [markdown]
# <a href="https://colab.research.google.com/github/preethipalanisamy12-source/customer-satisfaction-analysis-ml/blob/main/Flipkart_CSAT_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  Customer Satisfaction Analysis and Prediction Using Machine Learning

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
# ##### **Done by**         - Preethi P

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/preethipalanisamy12-source/customer-satisfaction-analysis-ml.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Problem Statement
#
# Customer satisfaction is an important indicator of the quality of customer service and overall customer experience. However, customer satisfaction can be influenced by several factors, such as the type of issue raised, communication channel, response and handling time, resolution status, product category, and other customer-service-related attributes.
#
# The objective of this project is to analyze customer support interactions to identify the key factors associated with customer satisfaction and dissatisfaction. The project will use exploratory data analysis to understand patterns in customer service interactions and identify areas that may contribute to lower satisfaction.
#
# In addition, a machine learning classification model will be developed to predict customer satisfaction based on the available customer support and interaction-related information. The results will be interpreted from a business perspective to identify potential areas for improving customer service, prioritizing dissatisfied customers, and supporting data-driven customer experience decisions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# =============================================================================
# IMPORTING REQUIRED LIBRARIES
# =============================================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# Visualization settings
sns.set_theme(style="whitegrid")

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# =============================================================================
# LOADING DATASET
# =============================================================================

DATA_URL = (
"https://raw.githubusercontent.com/preethipalanisamy12-source/customer-satisfaction-analysis-ml/refs/heads/main/Customer_support_data.csv"
)

try:
    df = pd.read_csv(DATA_URL)
    print("Dataset loaded successfully.")

except Exception as e:
    print(f"Error while loading the dataset: {e}")

# %% [markdown]
# ### Dataset First View

# %%
# Display the first five records
df.head()

# %%
# Display the last five records
df.tail()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print(f"Number of observations : {df.shape[0]}")
print(f"Number of variables    : {df.shape[1]}")

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

duplicate_count = df.duplicated().sum()

print(f"Number of duplicate rows: {duplicate_count}")

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

missing_summary = pd.DataFrame({
    "Missing Count": df.isnull().sum(),
    "Missing Percentage": (df.isnull().mean() * 100).round(2)
})

missing_summary = (
    missing_summary[missing_summary["Missing Count"] > 0]
    .sort_values("Missing Count", ascending=False)
)

display(missing_summary)

# %%
# Visualizing the missing values

plt.figure(figsize=(14, 7))

sns.heatmap(
    df.isnull(),
    cbar=False,
    yticklabels=False
)

plt.title("Missing Value Pattern in the Dataset")
plt.xlabel("Variables")
plt.ylabel("Records")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# - The dataset contains 85,907 customer support interactions.
# - It includes 20 variables covering customer details, support interactions, issue information, agent information, order information, and customer satisfaction.
# - The main outcome variable is CSAT Score, representing customer satisfaction with the support experience.
# - The dataset contains both categorical and numerical variables.
# - Important operational variables include channel_name, category, Sub-category, connected_handling_time, Agent_name, Agent Shift, and Tenure Bucket.
# - Customer and transaction-related information includes Customer_City, Product_category, Item_price, and Order_id.
# - The dataset also contains multiple date/time fields (order_date_time, Issue_reported_at, issue_responded, Survey_response_Date) that can be used to derive response-time and other time-based features.
# - Customer Remarks contains free-text feedback and requires special treatment because it includes both actual missing values and placeholders like None, -, and N/A.
# - The dataset provides enough information for exploratory analysis of customer satisfaction and classification-based prediction of satisfaction.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
#Dataset columns
df.columns.tolist()

# %%
# Dataset Describe
df.describe(include = 'all').T

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - **Unique id / Order_id** — identifiers for the ticket and the linked order (Order_id has many missing values, as noted above)
# - **channel_name** — how the ticket was raised (Email, Inbound call, Outcall)
# - **category / Sub-category** — the type of issue the ticket is about (e.g. Returns, Order Related, Payments)
# - **Customer Remarks** — free-text feedback left by the customer (optional, often blank)
# - **Order_date_time, Issue_reported at, issue_responded, Survey_response_Date** — timestamps tracking the ticket lifecycle
# - **Customer_City, Item_price, Product_category** — order/product context, only present for order-linked tickets
# - **connected_handling_time** — talk-time on the call (almost entirely missing)
# - **Agent_name, Supervisor, Manager, Agent Shift, Tenure Bucket** — details about the agent who handled the ticket
# - **CSAT Score** — the target variable: the customer's satisfaction rating from 1 (worst) to 5 (best)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# --- Drop almost-empty columns ---
df = df.drop(columns=['connected_handling_time'])

# --- Handle missing values ---
df['Customer Remarks'] = df['Customer Remarks'].fillna('')   # empty string for text
df['Item_price'] = df['Item_price'].fillna(0)                # 0 for missing price

# --- Convert timestamps to datetime ---
df['Issue_reported at'] = pd.to_datetime(
    df['Issue_reported at'], format='mixed', dayfirst=True, errors='coerce'
)
df['issue_responded'] = pd.to_datetime(
    df['issue_responded'], format='mixed', dayfirst=True, errors='coerce'
)

# --- Engineer sentiment score and length from the customer's written remark ---
df['has_remark'] = df['Customer Remarks'].notna().astype(int)
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
df['remark_sentiment'] = df['Customer Remarks'].apply(lambda t: sia.polarity_scores(t)['compound'] if t else 0.0)
df['remark_len'] = df['Customer Remarks'].str.len()

# --- Create target variable (Satisfaction flag) ---
# 1 = Satisfied (CSAT 4 or 5), 0 = At-Risk (CSAT 1, 2 or 3)
df['Satisfaction'] = (df['CSAT Score'] >= 4).astype(int)

df.info()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ## Data Manipulations
# - Dropped column: `connected_handling_time` (mostly empty).
# - Handled missing values:
#   - `Customer Remarks` → filled with empty string.
#   - `Item_price` → filled with 0.
# - Converted timestamps: `Issue_reported at`, `issue_responded` → datetime format.
# - Created target variable: `Satisfaction` (binary flag from CSAT Score).
#
# ## Insights
# - Core fields (`channel_name`, `category`, `Agent_name`, etc.) are complete.
# - Transactional fields (`Order_id`, `order_date_time`, `Customer_City`, `Product_category`) show high missingness.
# - `Customer Remarks` and `Item_price` are now standardized for analysis.
# - Time columns are clean, enabling response time or time-based feature engineering.
# - Satisfaction outcome is clearly defined for classification tasks.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(7,5))
ax = sns.countplot(x='CSAT Score', data=df, palette='rocket')
plt.title('Distribution of CSAT Score')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is the simplest, clearest way to show how many tickets fall into each score category — since CSAT Score is a small set of discrete values (1 to 5), a bar per value is easier to read than a histogram.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution is heavily skewed towards 5 and Scores of 2 and 3 are rare.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — it's a positive signal that the large majority of tickets are already rated well, meaning the core support process is generally working. But it also means a model that always predicts '5' would look deceptively accurate, which could hide real problems if the business relied on accuracy alone as a KPI.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(7,5))
ax = sns.countplot(x='Satisfaction', data=df, palette='rocket')
plt.xticks([0,1], ['At-Risk (0)', 'Satisfied (1)'])
plt.title('Distribution of the Binary Target: Satisfaction')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This is the actual target variable the models will be trained on, so it's worth visualizing on its own to see exactly how imbalanced it is, separate from the original 5-class distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Around 85% Satisfied vs 15% At-Risk. Still imbalanced, but far less extreme than the original 5-way split, and much more learnable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive impact: it confirms the binary framing is a reasonable modeling choice. It also tells the business that roughly 1 in 7 tickets ends in a dissatisfied customer — a concrete number to set a target against for improvement.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(7,5))
ax = sns.countplot(x='channel_name', data=df, order=df['channel_name'].value_counts().index, palette='rocket')
plt.title('Ticket Volume by Channel')
plt.xlabel('Channel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot shows which support channels handle the most volume, which is useful context before looking at how CSAT varies by channel next.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of tickets come through Inbound calls, with Email and Outcall making up smaller shares.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Useful for resourcing decisions — if one channel dominates volume, that's where process improvements will have the biggest overall impact on satisfaction.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(7,5))
sns.histplot(
    data=df,
    x="channel_name",
    hue="Satisfaction",
    multiple="fill",
    palette={0:"red", 1:"blue"},
    shrink=0.8
)
plt.title("Satisfaction Rate by Channel")
plt.ylabel("Proportion")
plt.xticks(rotation=0)
plt.legend(title="", labels=["Satisfied","At-Risk"])
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A stacked, normalized bar chart makes it easy to compare the proportion of satisfied vs at-risk customers across channels, regardless of how many tickets each channel has.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Satisfaction rates are fairly similar across channels, with only small differences — channel alone does not appear to be a dominant driver of satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# No strong positive or negative signal here on its own, but it rules out 'channel choice' as a quick fix — the business shouldn't expect satisfaction to improve much just by shifting ticket volume between channels.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

top_categories = df['category'].value_counts().head(8).index

plt.figure(figsize=(8,5))
sns.histplot(
    data=df[df['category'].isin(top_categories)],
    y="category",
    hue="Satisfaction",
    multiple="fill",
    palette={0:"red", 1:"blue"}
)
plt.title("Satisfaction Rate by Category (Top 8 by volume)")
plt.xlabel("Proportion")
plt.ylabel("")
plt.legend(title="", labels=["At-Risk","Satisfied"])
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal stacked bar chart handles the longer category names better than a vertical one, while still comparing satisfaction proportions across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some categories have a noticeably higher at-risk proportion than others — issue category is one of the more informative features for predicting satisfaction, more so than channel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact: categories with the worst satisfaction rates can be prioritized for root-cause review by the support/product teams — this points to where to focus improvement effort.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

df['response_time_min'] = (df['issue_responded'] - df['Issue_reported at']).dt.total_seconds() / 60
df.loc[df['response_time_min'] < 0, 'response_time_min'] = np.nan
df['response_time_min'] = df['response_time_min'].fillna(df.groupby('category')['response_time_min'].transform('median'))
df['response_time_min'] = df['response_time_min'].fillna(df['response_time_min'].median())

plt.figure(figsize=(7,5))
sns.histplot(df['response_time_min'].clip(upper=200), bins=40)
plt.title('Distribution of Response Time (minutes)')
plt.xlabel('Response Time (minutes)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is the standard way to see the shape of a continuous variable's distribution — here it shows response time is heavily right-skewed, with most tickets resolved quickly and a long tail of slow ones.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most tickets get a response within the first 30-40 minutes, but there is a long tail of tickets that take much longer — these slow-response tickets are worth checking against satisfaction next.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Not a business insight on its own yet, but it justifies treating response time as a skewed variable that will need outlier handling before modeling.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(7,5))
sns.boxplot(x='Satisfaction', y='response_time_min', data=df[df['response_time_min'] < df['response_time_min'].quantile(0.95)])
plt.xticks([0,1], ['At-Risk', 'Satisfied'])
plt.title('Response Time vs Satisfaction (95th percentile and below)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is the best way to compare the spread and median of a numeric variable (response time) across two groups (Satisfied vs At-Risk).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# At-risk tickets tend to have noticeably longer response times than satisfied ones — this matches the intuitive idea that slower support leads to unhappier customers, and it's one of the stronger relationships found in this EDA.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Strong positive business impact: this is a directly actionable insight. Reducing response time, especially for the slowest tickets, is likely to reduce the at-risk rate.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

plt.figure(figsize=(7,5))
sns.histplot(df.loc[df['has_remark']==1, 'remark_sentiment'], bins=30)
plt.title('Distribution of Customer Remark Sentiment (VADER compound score)')
plt.xlabel('Sentiment Score (-1 = very negative, +1 = very positive)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(7,5))
sns.histplot(
    data=df,
    x="Agent Shift",
    hue="Satisfaction",
    multiple="fill",
    palette={0:"red", 1:"blue"}
)
plt.title("Satisfaction Rate by Agent Shift")
plt.ylabel("Proportion")
plt.xticks(rotation=0)
plt.legend(title="", labels=["Satisfied","At-Risk"])
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Stacked, normalized bar chart, to compare satisfaction proportions fairly across shifts with different ticket volumes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Satisfaction rates are broadly similar across shifts, with only minor variation — shift alone doesn't appear to be a strong differentiator.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Low direct business impact on its own, but rules out 'which shift is under-performing' as the main lever — the issue is more likely tied to ticket type or response speed than to which shift handled it.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(7,5))
sns.histplot(
    data=df,
    x="Tenure Bucket",
    hue="Satisfaction",
    multiple="fill",
    palette={0:"red", 1:"blue"}
)
plt.title("Satisfaction Rate by Agent Tenure Bucket")
plt.ylabel("Proportion")
plt.xticks(rotation=0)
plt.legend(title="", labels=["Satisfied","At Risk"])
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Stacked bar approach, applied to agent tenure to see whether more experienced agents produce better satisfaction outcomes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a mild trend, but it is not dramatic — tenure alone does not strongly separate satisfied from at-risk outcomes in this data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Modest business relevance: it suggests training/experience is not the primary lever for satisfaction here, so investment might be better spent on process changes like response time (Chart 7) than purely on agent seniority.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

plt.figure(figsize=(7,5))
sns.boxplot(x=df.loc[df['Item_price']>0, 'Item_price'])
plt.title('Item Price Distribution (orders with a price > 0)')
plt.xlabel('Item Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is the standard chart for spotting outliers in a continuous variable at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Item price has a number of high-value outliers pulling the distribution to the right, but the bulk of orders are concentrated at lower price points.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Low direct impact on satisfaction prediction , but useful to know before deciding how to treat this column in the outlier-handling step later.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
df['report_hour'] = df['Issue_reported at'].dt.hour

plt.figure(figsize=(9,5))
sns.countplot(x='report_hour', data=df, palette='rocket')
plt.title('Ticket Volume by Hour of Day')
plt.xlabel('Hour Reported (24h)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot across 24 hours is the natural way to see when ticket volume peaks during the day.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Ticket volume is not evenly spread across the day — there are clear peak hours, which is normal for a support operation tied to customer activity and business hours.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Operationally useful for staffing decisions: knowing peak hours helps schedule enough agents to keep response times low during busy periods, which Chart 7 showed is linked to satisfaction.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numeric_cols = ['response_time_min', 'remark_sentiment', 'remark_len', 'Item_price',
                 'report_hour', 'has_remark', 'Satisfaction']
plt.figure(figsize=(9,7))
sns.heatmap(df[numeric_cols].corr(), annot=True, fmt='.2f', cmap='rocket_r', center=0)
plt.title('Correlation Heatmap of Numeric Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is the standard way to see linear correlation between every pair of numeric features at once, including how each one relates to the target.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# No feature is very strongly correlated with Satisfaction in a simple linear sense (the strongest, sentiment, is still a weak correlation). This matches what the box plots already suggested  so this is a dataset where satisfaction depends on many small factors together, not one dominant linear driver.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sample_df = df[['response_time_min', 'remark_sentiment', 'remark_len', 'Satisfaction']].sample(2000, random_state=42)
sns.pairplot(sample_df, hue='Satisfaction')
plt.suptitle('Pair Plot of Key Numeric Features by Satisfaction', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot shows pairwise relationships and individual distributions together, colored by the target — useful for spotting whether any two features combined separate the classes better than either does alone. A 2,000-row sample is used to keep the plot fast and readable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Satisfied and At-Risk classes overlap heavily on every pair of features — there's no single pair that cleanly separates them visually. This reinforces that the models will need to combine several weak signals together (which tree-based ensembles are naturally good at) rather than relying on any one strong feature.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Based on the charts above, three relationships stood out as worth testing formally rather than judging by eye alone: response time, remark sentiment, and support channel.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
